# %% [markdown]
# # For loop practice

# %%
fam = ["Father" , "Mother" , "Children"]
for height in fam:
  print(height)
# Out:
# Father
# Mother
# Children

# %%
member = ["Father" , "Mother" , "Children"]
for member in fam:
  print(fam)
# Out:
# ['Father', 'Mother', 'Children']
# ['Father', 'Mother', 'Children']
# ['Father', 'Mother', 'Children']

# %%
#to test booleans
1.5 == 7
if 1.5 != 7:
  print(True)
else:
  print(False)
# Out:
# True

# %%
list = [10, 20 , 30 , 40 , 15]
for marks in list:
  marks = marks - 10
  print(marks)
# Out:
# 0
# 10
# 20
# 30
# 5

# %%
name = "John"
for letter in name:
  print(str(letter) + "- is a letter in the name John")
# Out:
# J- is a letter in the name John
# o- is a letter in the name John
# h- is a letter in the name John
# n- is a letter in the name John
